# %%
import pandas as pd
pd.read_parquet(r'alfabattle2_train_transactions_contest\train_transactions_contest\part_000_0_to_23646.parquet', engine='pyarrow')
# Out:
#         app_id      amnt  currency  operation_kind  card_type  operation_type  \
# 0            0  0.465425         1               4         98               4
# 1            0  0.000000         1               2         98               7
# 2            0  0.521152         1               2         98               3
# 3            0  0.356078         1               1          5               2
# 4            0  0.000000         1               2         98               7
# ...        ...       ...       ...             ...        ...             ...
# 105226   23646  0.390944         1               1         37               2
# 105227   23646  0.428447         1               1         37               2
# 105228   23646  0.371478         1               1         37               2
# 105229   23646  0.348726         1               1         37               2
# 105230   23646  0.324316         1               1         37               2
#
# ...

# %%
pd.read_parquet(r'alfabattle2_train_transactions_contest\train_transactions_contest\part_001_23647_to_47415.parquet', engine='pyarrow')
# Out:
#         app_id      amnt  currency  operation_kind  card_type  operation_type  \
# 111110   23647  0.309831         1               1         42               2
# 111111   23647  0.310942         1               1         54               2
# 111112   23647  0.308504         1               1         54               2
# 111113   23647  0.249951         1               1         54               2
# 111114   23647  0.296745         1               1         42               2
# ...        ...       ...       ...             ...        ...             ...
# 224261   47415  0.452767         1               1          1               1
# 224262   47415  0.320248         1               1          1               1
# 224263   47415  0.321173         1               1          1              13
# 224264   47415  0.363015         1               1          1               1
# 224265   47415  0.266500         1               1          1               1
#
# ...

# %%
pd.read_parquet(r'alfabattle2_train_transactions_contest\train_transactions_contest\part_028_595746_to_615602.parquet', engine='pyarrow')
# Out:
#          app_id      amnt  currency  operation_kind  card_type  \
# 3001943  595746  0.546607         1               2         10
# 3001944  595746  0.348838         1               1         10
# 3001945  595746  0.352417         1               1         10
# 3001946  595746  0.353044         1               1         10
# 3001947  595746  0.348838         1               1         10
# ...         ...       ...       ...             ...        ...
# 3159145  615602  0.334495         1               1         23
# 3159146  615602  0.410411         1               2         23
# 3159147  615602  0.387677         1               2         23
# 3159148  615602  0.262524         1               1         23
# 3159149  615602  0.348838         1               2         23
#
#          operation_type  operation_type_group  ecommerce_flag  payment_system  \
# 3001943               3                     1               1               3
# ...

# %%
# !pip install pyarrow
# Out:
# ...
#      ---------------------------------------- 17.9/17.9 MB 9.9 MB/s eta 0:00:00
# ...
